# %% [markdown]
# Clonar el conjunto de datos requerido de los que te fueron proporcionados

# %%
#Clonar el conjunto de datos requerido
# !git clone https://github.com/bjsfsmx-0544/PROC111-V1-plantilla-proyecto
# !pip install tensorflow
# !pip install keras
# Out:
# Cloning into 'PROC111-V1-plantilla-proyecto'...
# remote: Enumerating objects: 803, done.
# remote: Counting objects: 100% (3/3), done.
# remote: Compressing objects: 100% (3/3), done.
# remote: Total 803 (delta 0), reused 0 (delta 0), pack-reused 800
# Receiving objects: 100% (803/803), 2.07 MiB | 15.83 MiB/s, done.
# ...

# %% [markdown]
# Mostrar la primera imagen del entrenamiento

# %%
vdbhjkkdnb bnjkldm lsxksxljbswlkjbskjsbgslkjisgblsiogsghdgdjasvjjopsdbkdvjjdj shlsosbmenszbdjsmas

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import matplotlib.pyplot as plt
from matplotlib.image import imread

training_damaged_image = "/content/PROC111-V1-plantilla-proyecto/train/damage/image (20).jpeg"
training_image_directory = "/content/PROC111-V1-plantilla-proyecto/train"

# Cargar los pixeles de la imagen
image = imread(training_damaged_image)
training_data_generator = ImageDataGenerator(zoom_range=0.3, horizontal_flip=True, fill_mode='nearest')

plt.title("Dañado: Imagen 60")

# Graficar los datos de los pixeles sin procesar
plt.imshow(image)

# Mostrar la imagen
plt.show()

# %% [markdown]
# Realizar una generación artificial en el conjunto de datos de entrenamiento

# %%
# Zoom y giro horizontal (o cualquier técnica de generación artificial de datos de tu preferencia)
import tensorflow
from tensorflow.keras.preprocessing.image import ImageDataGenerator

training_data_generator = ImageDataGenerator(zoom_range=0.3, horizontal_flip=True, fill_mode='nearest')

# %% [markdown]
# Visualización de las imágenes generadas artificialmente en 4 subfiguras

# %%
# Visualización de la imagen procesada

training_image_directory = "/content/PROC111-V1-plantilla-proyecto/train"
